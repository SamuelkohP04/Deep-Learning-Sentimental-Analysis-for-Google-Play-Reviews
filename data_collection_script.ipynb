# %% [markdown]
# Install `google-play-scraper` package using: `pip install google-play-scraper`
#
#
# Please refer to https://pypi.org/project/google-play-scraper/ for details.

# %%
from google_play_scraper import Sort, reviews, reviews_all
import pandas as pd

# %%
# initialization

app_name = 'com.netflix.mediaclient' # found in app's url

rvws, token = reviews(
    app_name,           # found in app's url
    lang='en',        # defaults to 'en'
    country='us',     # defaults to 'us'
    sort=Sort.NEWEST, # start with most recent
    count=200       # batch size, set as 200 since 200 reviews per page
)

app_reviews = rvws
batch_num=1

# %%
# Loop through the number of batches
for batch in range(500): # You can adjust the number of batches to collect more or less reviews
    rvws, token = reviews( # store continuation_token
        app_name,
        lang='en',
        country='us',
        sort=Sort.NEWEST,
        count=200,
        # using token obtained from previous batch
        continuation_token=token
    )
    app_reviews.extend(rvws)
    batch_num +=1

# %%
df = pd.DataFrame.from_records(app_reviews)
df
# Out:
#                                     reviewId  \
# 0       3444e727-30f0-475f-9386-987810effd63
# 1       feecc937-4eb7-44fd-8539-2ec8368e8a1b
# 2       9b736bd6-74cd-417a-9375-298748c65303
# 3       90d2f931-3a2d-4929-b7db-67ec70fb198b
# 4       760e4d2e-fd0d-4b9a-b0d6-2cec5a7daa33
# ...                                      ...
# 100195  f2ce51c0-47e2-4aea-8102-7d4c59bbc774
# 100196  311a5081-020d-4049-94c9-69bbc82056c5
# 100197  f8c66871-758b-440c-b8dd-8fd15915b324
# 100198  1de01fb9-d191-4c92-a7e8-0fb47075495d
# 100199  02a1f63f-ca16-4f25-b459-8883ed991160
#
#                                        userName  \
# 0                                Ranjith Roshan
# 1                               Federico Canedo
# 2                                    Usha Parge
# 3       Saman Afridi why not she visit her home
# 4                                  Neeraj kumar
# ...                                         ...
# 100195                        jonathan lissmore
# 100196                       Nirosheni Fernando
# 100197                              Randy Enoch
# 100198                         MD JEWEL Mai SAK
# 100199                             Chris Knight
#
#                                                 userImage  \
# 0       https://play-lh.googleusercontent.com/a-/ALV-U...
# 1       https://play-lh.googleusercontent.com/a/ACg8oc...
# 2       https://play-lh.googleusercontent.com/a/ACg8oc...
# 3       https://play-lh.googleusercontent.com/a/ACg8oc...
# 4       https://play-lh.googleusercontent.com/a-/ALV-U...
# ...                                                   ...
# 100195  https://play-lh.googleusercontent.com/a-/ALV-U...
# 100196  https://play-lh.googleusercontent.com/a/ACg8oc...
# 100197  https://play-lh.googleusercontent.com/a/ACg8oc...
# 100198  https://play-lh.googleusercontent.com/a-/ALV-U...
# 100199  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                                   content  score  \
# 0                     All okay please release more series      5
# 1       Qué bueno que agregaron los juegos, lástima qu...      1
# 2       My all accounts are turned in children automat...      1
# 3                                I like because of series      5
# 4       Anti hindu content on netflix, many times peop...      1
# ...                                                   ...    ...
# 100195                                         It's great      5
# 100196  This is sooooooooooo good! I can watch all new...      5
# 100197                            It's nice and I love it      5
# 100198                                             Okokok      5
# 100199            Can no longer stream via ChromeCast :-(      1
#
#         thumbsUpCount   reviewCreatedVersion                  at replyContent  \
# 0                   1                   None 2024-01-08 01:23:11         None
# 1                   0  8.96.1 build 16 50568 2024-01-08 01:18:03         None
# 2                   0   8.90.1 build 7 50522 2024-01-08 01:17:55         None
# 3                   0  8.96.1 build 16 50568 2024-01-08 01:17:38         None
# 4                   0  8.96.1 build 16 50568 2024-01-08 01:16:33         None
# ...               ...                    ...                 ...          ...
# 100195              0  8.52.2 build 14 50335 2022-12-26 17:26:58         None
# 100196              0                   None 2022-12-26 17:25:05         None
# 100197              0                   None 2022-12-26 17:24:22         None
# 100198              0  8.52.2 build 14 50335 2022-12-26 17:19:14         None
# 100199              0  8.52.2 build 14 50335 2022-12-26 17:13:54         None
#
#        repliedAt             appVersion
# 0           None                   None
# 1           None  8.96.1 build 16 50568
# 2           None   8.90.1 build 7 50522
# 3           None  8.96.1 build 16 50568
# 4           None  8.96.1 build 16 50568
# ...          ...                    ...
# 100195      None  8.52.2 build 14 50335
# 100196      None                   None
# 100197      None                   None
# 100198      None  8.52.2 build 14 50335
# 100199      None  8.52.2 build 14 50335
#
# [100200 rows x 11 columns]

# %%
df.to_csv('pokemongo_reviews.csv',index=False)

# %%
df.score.value_counts()
# Out:
# 1    45100
# 5    38658
# 4     6991
# 3     4892
# 2     4559
# Name: score, dtype: int64
